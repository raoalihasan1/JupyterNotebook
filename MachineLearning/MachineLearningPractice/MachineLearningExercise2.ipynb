# %% [markdown]
# # Machine Learning Exercise 2

# %% [markdown]
# ### Step 1
# Import The Modules Required To Perform The Task And Read In The CSV File Into A DataFrame. Next, Explore The Data, Its Structure And Columns To Gain An Understanding Of What The CSV File Consists Of And The Type Of Data Present.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
dfMedicalInsurance = pd.read_csv('medicalInsurance.csv')
dfMedicalInsurance.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %% [markdown]
# ### Step 2
# Perform Data Wrangling To Transform The Sex, Smoker And Region Columns From Their Original Format To An Encoded Format In Order To Be Able To Perform Machine Learning On The Data.

# %%
dfMedicalInsurance['sex'] = dfMedicalInsurance['sex'].map({'female': 1, 'male': 0, }).astype(int)
dfMedicalInsurance['smoker'] = dfMedicalInsurance['smoker'].map({'yes': 1, 'no': 0, }).astype(int)
dfMedicalInsurance['region'] = dfMedicalInsurance['region'].map({'southeast': 0, 'northeast': 1, 
                                                                 'southwest': 2, 'northwest': 3, }).astype(int)
dfMedicalInsurance.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       2  16884.92400
# 1   18    0  33.770         1       0       0   1725.55230
# 2   28    0  33.000         3       0       0   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520
# 5   31    1  25.740         0       0       0   3756.62160
# 6   46    1  33.440         1       0       0   8240.58960
# 7   37    1  27.740         3       0       3   7281.50560
# 8   37    0  29.830         2       0       1   6406.41070
# 9   60    1  25.840         0       0       3  28923.13692

# %% [markdown]
# ### Step 3
# Use Matplotlib To Generate Graphs So You Develop An Understanding Of The Distribution And The Relationship Between The Variables To See How The Different Variables In The Dataset Affect The Medical Insurance Charge.

# %%
plt.figure(figsize=(14, 10))
plt.hist(dfMedicalInsurance["charges"], color='#E3242B')
plt.xlabel("Medical Insurance Charge")
plt.ylabel("Frequency")
plt.title("The Cost Of Medical Insurance")
plt.rc("font", size=13)
plt.show()

# %%
plt.figure(figsize=(14, 10))
plt.pie(dfMedicalInsurance["region"].value_counts(), 
        labels=['South East', 'South West', 'North West', 'North East'], 
        startangle=90, 
        autopct='%1.1f%%',
        colors=['#03C04A','#1AA7EC', '#FFA500', '#F9C70C'])
plt.gca().add_artist(plt.Circle((0,0), 0.725, fc='white'))
plt.rc('font', size=13)
plt.title('Percentage Of People From Each Region In The Dataset')
plt.axis('equal')  
plt.show()

# %%
plt.figure(figsize=(14, 10))
plt.grid(linestyle = '--', linewidth = 2, alpha=0.5)
plt.scatter(dfMedicalInsurance["bmi"], dfMedicalInsurance["charges"], color='#E3242B')
plt.xlabel("Body Mass Index (BMI)")
plt.ylabel("Cost Of Medical Insurance")
plt.title("Relationship Between BMI And Cost Of Medical Insurance")
plt.rc("font", size=13)
plt.show()

# %% [markdown]
# ### Step 4
# Perform Machine Learning Using The Imported Libraries To Predict How All The Variables Affect The Medical Insurance Charge. After Completing The Model, Calculate The $R^{2} Score$ Of It To Determine The Accuracy Of Your Predictions And Display the Results For Each Individual In the Test data With Their Details.

# %%
X = dfMedicalInsurance.drop(columns=['charges'])
Y = dfMedicalInsurance["charges"]
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.25)
trainingModel = DecisionTreeRegressor()
trainingModel.fit(trainX, trainY)
predictionResults = trainingModel.predict(testX)
print("This Model Has An R2 Score Of: ", round(r2_score(testY, predictionResults), 2))
# Out:
# This Model Has An R2 Score Of:  0.78

# %%
testX.reset_index(drop=True, inplace=True)
testY = testY.tolist()
for i in range(len(testX)):
        
        x = testX.loc[i]
        
        if(x['sex'] == 1):
            gender = "Female"
        elif(x['sex'] == 0):
            gender = "Male"
        else:
            gender = "Unknown"
            
        if(x['smoker'] == 1):
            smoker = "Smoker"
        elif(x['smoker'] == 0):
            smoker = "Non-Smoker"
        else:
            smoker = "Unknown"
        
        if(x['region'] == 0):
            region = "South East"
        elif(x['region'] == 1):
            region = "North East"
        elif(x['region'] == 2):
            region = "South West"
        elif(x['region'] == 3):
            region = "North West"
        else:
            region = "Unknown"
        
        print("Details Of Patient " + str(i + 1) + ":")
        print("Age:", int(x['age']))
        print("Gender:", gender)
        print("BMI:", x['bmi'])
        print("No. Of Children:", int(x['children']))
        print("Smoker:", smoker)
        print("Region:", region)
        print("---------------------------------------------------")
        print("Estimated Medical Insurance (From Model): $" + str(round(predictionResults[i], 2)))
        print("---------------------------------------------------")
        print("Actual Medical Insurance: $" + str(round(testY[i], 2)))
        print("---------------------------------------------------\n")
# Out:
# Details Of Patient 1:
# Age: 21
# Gender: Male
# BMI: 31.1
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1909.53
# ---------------------------------------------------
# Actual Medical Insurance: $1526.31
# ---------------------------------------------------
#
# Details Of Patient 2:
# Age: 29
# Gender: Female
# BMI: 32.11
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4433.92
# ---------------------------------------------------
# Actual Medical Insurance: $4922.92
# ---------------------------------------------------
#
# Details Of Patient 3:
# Age: 58
# Gender: Male
# BMI: 38.0
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11362.76
# ---------------------------------------------------
# Actual Medical Insurance: $11365.95
# ---------------------------------------------------
#
# Details Of Patient 4:
# Age: 46
# Gender: Male
# BMI: 42.35
# No. Of Children: 3
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $41949.24
# ---------------------------------------------------
# Actual Medical Insurance: $46151.12
# ---------------------------------------------------
#
# Details Of Patient 5:
# Age: 50
# Gender: Male
# BMI: 32.205
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8116.68
# ---------------------------------------------------
# Actual Medical Insurance: $8835.26
# ---------------------------------------------------
#
# Details Of Patient 6:
# Age: 61
# Gender: Male
# BMI: 36.3
# No. Of Children: 1
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $48517.56
# ---------------------------------------------------
# Actual Medical Insurance: $47403.88
# ---------------------------------------------------
#
# Details Of Patient 7:
# Age: 63
# Gender: Male
# BMI: 36.765
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $13555.0
# ---------------------------------------------------
# Actual Medical Insurance: $13981.85
# ---------------------------------------------------
#
# Details Of Patient 8:
# Age: 24
# Gender: Female
# BMI: 30.1
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3981.98
# ---------------------------------------------------
# Actual Medical Insurance: $4234.93
# ---------------------------------------------------
#
# Details Of Patient 9:
# Age: 61
# Gender: Male
# BMI: 33.915
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $13143.34
# ---------------------------------------------------
# Actual Medical Insurance: $13143.86
# ---------------------------------------------------
#
# Details Of Patient 10:
# Age: 34
# Gender: Male
# BMI: 42.13
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6356.27
# ---------------------------------------------------
# Actual Medical Insurance: $5124.19
# ---------------------------------------------------
#
# Details Of Patient 11:
# Age: 51
# Gender: Female
# BMI: 21.56
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9877.61
# ---------------------------------------------------
# Actual Medical Insurance: $9855.13
# ---------------------------------------------------
#
# Details Of Patient 12:
# Age: 26
# Gender: Male
# BMI: 32.49
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2904.09
# ---------------------------------------------------
# Actual Medical Insurance: $3490.55
# ---------------------------------------------------
#
# Details Of Patient 13:
# Age: 28
# Gender: Male
# BMI: 35.435
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2689.5
# ---------------------------------------------------
# Actual Medical Insurance: $3268.85
# ---------------------------------------------------
#
# Details Of Patient 14:
# Age: 21
# Gender: Female
# BMI: 21.85
# No. Of Children: 1
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $20167.34
# ---------------------------------------------------
# Actual Medical Insurance: $15359.1
# ---------------------------------------------------
#
# Details Of Patient 15:
# Age: 54
# Gender: Male
# BMI: 30.21
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $24476.48
# ---------------------------------------------------
# Actual Medical Insurance: $10231.5
# ---------------------------------------------------
#
# Details Of Patient 16:
# Age: 19
# Gender: Female
# BMI: 21.7
# No. Of Children: 0
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $14283.46
# ---------------------------------------------------
# Actual Medical Insurance: $13844.51
# ---------------------------------------------------
#
# Details Of Patient 17:
# Age: 50
# Gender: Male
# BMI: 37.07
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9304.7
# ---------------------------------------------------
# Actual Medical Insurance: $9048.03
# ---------------------------------------------------
#
# Details Of Patient 18:
# Age: 26
# Gender: Male
# BMI: 29.15
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3392.37
# ---------------------------------------------------
# Actual Medical Insurance: $2902.91
# ---------------------------------------------------
#
# Details Of Patient 19:
# Age: 20
# Gender: Male
# BMI: 29.735
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1639.56
# ---------------------------------------------------
# Actual Medical Insurance: $1769.53
# ---------------------------------------------------
#
# Details Of Patient 20:
# Age: 58
# Gender: Male
# BMI: 30.305
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11763.0
# ---------------------------------------------------
# Actual Medical Insurance: $11938.26
# ---------------------------------------------------
#
# Details Of Patient 21:
# Age: 32
# Gender: Female
# BMI: 28.93
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4544.23
# ---------------------------------------------------
# Actual Medical Insurance: $3972.92
# ---------------------------------------------------
#
# Details Of Patient 22:
# Age: 41
# Gender: Male
# BMI: 35.75
# No. Of Children: 1
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $39871.7
# ---------------------------------------------------
# Actual Medical Insurance: $40273.65
# ---------------------------------------------------
#
# Details Of Patient 23:
# Age: 60
# Gender: Male
# BMI: 39.9
# No. Of Children: 0
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $48970.25
# ---------------------------------------------------
# Actual Medical Insurance: $48173.36
# ---------------------------------------------------
#
# Details Of Patient 24:
# Age: 35
# Gender: Male
# BMI: 24.13
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4894.75
# ---------------------------------------------------
# Actual Medical Insurance: $5125.22
# ---------------------------------------------------
#
# Details Of Patient 25:
# Age: 33
# Gender: Male
# BMI: 35.245
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4518.83
# ---------------------------------------------------
# Actual Medical Insurance: $12404.88
# ---------------------------------------------------
#
# Details Of Patient 26:
# Age: 51
# Gender: Male
# BMI: 22.42
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8688.86
# ---------------------------------------------------
# Actual Medical Insurance: $9361.33
# ---------------------------------------------------
#
# Details Of Patient 27:
# Age: 41
# Gender: Male
# BMI: 32.2
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7160.09
# ---------------------------------------------------
# Actual Medical Insurance: $6875.96
# ---------------------------------------------------
#
# Details Of Patient 28:
# Age: 53
# Gender: Male
# BMI: 30.495
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $27346.04
# ---------------------------------------------------
# Actual Medical Insurance: $10072.06
# ---------------------------------------------------
#
# Details Of Patient 29:
# Age: 39
# Gender: Male
# BMI: 28.3
# No. Of Children: 1
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $22462.04
# ---------------------------------------------------
# Actual Medical Insurance: $21082.16
# ---------------------------------------------------
#
# Details Of Patient 30:
# Age: 35
# Gender: Male
# BMI: 27.74
# No. Of Children: 2
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $20009.63
# ---------------------------------------------------
# Actual Medical Insurance: $20984.09
# ---------------------------------------------------
#
# Details Of Patient 31:
# Age: 64
# Gender: Male
# BMI: 39.16
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $16085.13
# ---------------------------------------------------
# Actual Medical Insurance: $14418.28
# ---------------------------------------------------
#
# Details Of Patient 32:
# Age: 58
# Gender: Male
# BMI: 25.175
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11534.87
# ---------------------------------------------------
# Actual Medical Insurance: $11931.13
# ---------------------------------------------------
#
# Details Of Patient 33:
# Age: 59
# Gender: Female
# BMI: 23.655
# No. Of Children: 0
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $27037.91
# ---------------------------------------------------
# Actual Medical Insurance: $25678.78
# ---------------------------------------------------
#
# Details Of Patient 34:
# Age: 37
# Gender: Female
# BMI: 38.39
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $43896.38
# ---------------------------------------------------
# Actual Medical Insurance: $40419.02
# ---------------------------------------------------
#
# Details Of Patient 35:
# Age: 31
# Gender: Male
# BMI: 36.3
# No. Of Children: 2
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $39774.28
# ---------------------------------------------------
# Actual Medical Insurance: $38711.0
# ---------------------------------------------------
#
# Details Of Patient 36:
# Age: 18
# Gender: Female
# BMI: 26.315
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2196.47
# ---------------------------------------------------
# Actual Medical Insurance: $2198.19
# ---------------------------------------------------
#
# Details Of Patient 37:
# Age: 26
# Gender: Female
# BMI: 29.355
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3392.37
# ---------------------------------------------------
# Actual Medical Insurance: $4564.19
# ---------------------------------------------------
#
# Details Of Patient 38:
# Age: 48
# Gender: Male
# BMI: 37.29
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8347.16
# ---------------------------------------------------
# Actual Medical Insurance: $8978.19
# ---------------------------------------------------
#
# Details Of Patient 39:
# Age: 22
# Gender: Male
# BMI: 19.95
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4296.27
# ---------------------------------------------------
# Actual Medical Insurance: $4005.42
# ---------------------------------------------------
#
# Details Of Patient 40:
# Age: 64
# Gender: Male
# BMI: 38.19
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $14210.54
# ---------------------------------------------------
# Actual Medical Insurance: $14410.93
# ---------------------------------------------------
#
# Details Of Patient 41:
# Age: 21
# Gender: Female
# BMI: 16.815
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2585.27
# ---------------------------------------------------
# Actual Medical Insurance: $3167.46
# ---------------------------------------------------
#
# Details Of Patient 42:
# Age: 20
# Gender: Female
# BMI: 28.975
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1737.38
# ---------------------------------------------------
# Actual Medical Insurance: $2257.48
# ---------------------------------------------------
#
# Details Of Patient 43:
# Age: 64
# Gender: Male
# BMI: 23.76
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $21223.68
# ---------------------------------------------------
# Actual Medical Insurance: $26926.51
# ---------------------------------------------------
#
# Details Of Patient 44:
# Age: 64
# Gender: Male
# BMI: 40.48
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $14319.03
# ---------------------------------------------------
# Actual Medical Insurance: $13831.12
# ---------------------------------------------------
#
# Details Of Patient 45:
# Age: 54
# Gender: Female
# BMI: 32.68
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10713.64
# ---------------------------------------------------
# Actual Medical Insurance: $10923.93
# ---------------------------------------------------
#
# Details Of Patient 46:
# Age: 46
# Gender: Male
# BMI: 33.345
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8334.59
# ---------------------------------------------------
# Actual Medical Insurance: $8334.46
# ---------------------------------------------------
#
# Details Of Patient 47:
# Age: 58
# Gender: Female
# BMI: 36.48
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12430.95
# ---------------------------------------------------
# Actual Medical Insurance: $12235.84
# ---------------------------------------------------
#
# Details Of Patient 48:
# Age: 43
# Gender: Female
# BMI: 34.58
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7345.73
# ---------------------------------------------------
# Actual Medical Insurance: $7727.25
# ---------------------------------------------------
#
# Details Of Patient 49:
# Age: 54
# Gender: Female
# BMI: 32.3
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10928.85
# ---------------------------------------------------
# Actual Medical Insurance: $11512.41
# ---------------------------------------------------
#
# Details Of Patient 50:
# Age: 43
# Gender: Female
# BMI: 26.7
# No. Of Children: 2
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $24520.26
# ---------------------------------------------------
# Actual Medical Insurance: $22478.6
# ---------------------------------------------------
#
# Details Of Patient 51:
# Age: 47
# Gender: Female
# BMI: 33.345
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8823.99
# ---------------------------------------------------
# Actual Medical Insurance: $20878.78
# ---------------------------------------------------
#
# Details Of Patient 52:
# Age: 49
# Gender: Male
# BMI: 25.6
# No. Of Children: 2
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $23967.38
# ---------------------------------------------------
# Actual Medical Insurance: $23306.55
# ---------------------------------------------------
#
# Details Of Patient 53:
# Age: 40
# Gender: Female
# BMI: 23.37
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7985.82
# ---------------------------------------------------
# Actual Medical Insurance: $8252.28
# ---------------------------------------------------
#
# Details Of Patient 54:
# Age: 43
# Gender: Female
# BMI: 25.08
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6837.37
# ---------------------------------------------------
# Actual Medical Insurance: $7325.05
# ---------------------------------------------------
#
# Details Of Patient 55:
# Age: 39
# Gender: Female
# BMI: 24.89
# No. Of Children: 3
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $19444.27
# ---------------------------------------------------
# Actual Medical Insurance: $21659.93
# ---------------------------------------------------
#
# Details Of Patient 56:
# Age: 37
# Gender: Female
# BMI: 17.29
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $27375.9
# ---------------------------------------------------
# Actual Medical Insurance: $6877.98
# ---------------------------------------------------
#
# Details Of Patient 57:
# Age: 22
# Gender: Male
# BMI: 26.84
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2155.68
# ---------------------------------------------------
# Actual Medical Insurance: $1665.0
# ---------------------------------------------------
#
# Details Of Patient 58:
# Age: 20
# Gender: Female
# BMI: 31.79
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2566.47
# ---------------------------------------------------
# Actual Medical Insurance: $3056.39
# ---------------------------------------------------
#
# Details Of Patient 59:
# Age: 60
# Gender: Male
# BMI: 32.8
# No. Of Children: 0
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $45008.96
# ---------------------------------------------------
# Actual Medical Insurance: $52590.83
# ---------------------------------------------------
#
# Details Of Patient 60:
# Age: 22
# Gender: Male
# BMI: 28.88
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2156.75
# ---------------------------------------------------
# Actual Medical Insurance: $2250.84
# ---------------------------------------------------
#
# Details Of Patient 61:
# Age: 28
# Gender: Female
# BMI: 28.88
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4350.51
# ---------------------------------------------------
# Actual Medical Insurance: $4337.74
# ---------------------------------------------------
#
# Details Of Patient 62:
# Age: 35
# Gender: Female
# BMI: 28.025
# No. Of Children: 0
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $20773.63
# ---------------------------------------------------
# Actual Medical Insurance: $20234.85
# ---------------------------------------------------
#
# Details Of Patient 63:
# Age: 18
# Gender: Male
# BMI: 23.085
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1704.57
# ---------------------------------------------------
# Actual Medical Insurance: $1704.7
# ---------------------------------------------------
#
# Details Of Patient 64:
# Age: 42
# Gender: Female
# BMI: 33.155
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7358.18
# ---------------------------------------------------
# Actual Medical Insurance: $7639.42
# ---------------------------------------------------
#
# Details Of Patient 65:
# Age: 50
# Gender: Female
# BMI: 30.115
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8116.68
# ---------------------------------------------------
# Actual Medical Insurance: $9910.36
# ---------------------------------------------------
#
# Details Of Patient 66:
# Age: 62
# Gender: Female
# BMI: 39.2
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $13470.8
# ---------------------------------------------------
# Actual Medical Insurance: $13470.86
# ---------------------------------------------------
#
# Details Of Patient 67:
# Age: 27
# Gender: Male
# BMI: 29.15
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $19350.37
# ---------------------------------------------------
# Actual Medical Insurance: $18246.5
# ---------------------------------------------------
#
# Details Of Patient 68:
# Age: 49
# Gender: Male
# BMI: 25.84
# No. Of Children: 2
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $23967.38
# ---------------------------------------------------
# Actual Medical Insurance: $23807.24
# ---------------------------------------------------
#
# Details Of Patient 69:
# Age: 44
# Gender: Female
# BMI: 27.5
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7421.19
# ---------------------------------------------------
# Actual Medical Insurance: $7626.99
# ---------------------------------------------------
#
# Details Of Patient 70:
# Age: 22
# Gender: Female
# BMI: 23.18
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2150.47
# ---------------------------------------------------
# Actual Medical Insurance: $2731.91
# ---------------------------------------------------
#
# Details Of Patient 71:
# Age: 49
# Gender: Male
# BMI: 31.35
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9964.06
# ---------------------------------------------------
# Actual Medical Insurance: $9290.14
# ---------------------------------------------------
#
# Details Of Patient 72:
# Age: 49
# Gender: Male
# BMI: 32.3
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10600.55
# ---------------------------------------------------
# Actual Medical Insurance: $10269.46
# ---------------------------------------------------
#
# Details Of Patient 73:
# Age: 54
# Gender: Female
# BMI: 46.7
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11093.62
# ---------------------------------------------------
# Actual Medical Insurance: $11538.42
# ---------------------------------------------------
#
# Details Of Patient 74:
# Age: 32
# Gender: Female
# BMI: 29.59
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3947.41
# ---------------------------------------------------
# Actual Medical Insurance: $4562.84
# ---------------------------------------------------
#
# Details Of Patient 75:
# Age: 32
# Gender: Female
# BMI: 17.765
# No. Of Children: 2
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $16776.3
# ---------------------------------------------------
# Actual Medical Insurance: $32734.19
# ---------------------------------------------------
#
# Details Of Patient 76:
# Age: 21
# Gender: Female
# BMI: 26.4
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1837.24
# ---------------------------------------------------
# Actual Medical Insurance: $2597.78
# ---------------------------------------------------
#
# Details Of Patient 77:
# Age: 42
# Gender: Male
# BMI: 28.31
# No. Of Children: 3
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $24915.22
# ---------------------------------------------------
# Actual Medical Insurance: $32787.46
# ---------------------------------------------------
#
# Details Of Patient 78:
# Age: 59
# Gender: Male
# BMI: 31.79
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12925.89
# ---------------------------------------------------
# Actual Medical Insurance: $12928.79
# ---------------------------------------------------
#
# Details Of Patient 79:
# Age: 20
# Gender: Female
# BMI: 28.785
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2196.47
# ---------------------------------------------------
# Actual Medical Insurance: $2457.21
# ---------------------------------------------------
#
# Details Of Patient 80:
# Age: 22
# Gender: Male
# BMI: 37.62
# No. Of Children: 1
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $37484.45
# ---------------------------------------------------
# Actual Medical Insurance: $37165.16
# ---------------------------------------------------
#
# Details Of Patient 81:
# Age: 45
# Gender: Male
# BMI: 23.56
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8302.54
# ---------------------------------------------------
# Actual Medical Insurance: $8603.82
# ---------------------------------------------------
#
# Details Of Patient 82:
# Age: 64
# Gender: Female
# BMI: 32.965
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $13822.8
# ---------------------------------------------------
# Actual Medical Insurance: $14692.67
# ---------------------------------------------------
#
# Details Of Patient 83:
# Age: 33
# Gender: Male
# BMI: 29.4
# No. Of Children: 4
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $5375.04
# ---------------------------------------------------
# Actual Medical Insurance: $6059.17
# ---------------------------------------------------
#
# Details Of Patient 84:
# Age: 30
# Gender: Female
# BMI: 32.4
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4433.92
# ---------------------------------------------------
# Actual Medical Insurance: $4149.74
# ---------------------------------------------------
#
# Details Of Patient 85:
# Age: 27
# Gender: Female
# BMI: 32.395
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4846.92
# ---------------------------------------------------
# Actual Medical Insurance: $18903.49
# ---------------------------------------------------
#
# Details Of Patient 86:
# Age: 39
# Gender: Male
# BMI: 29.6
# No. Of Children: 4
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $15828.82
# ---------------------------------------------------
# Actual Medical Insurance: $7512.27
# ---------------------------------------------------
#
# Details Of Patient 87:
# Age: 22
# Gender: Male
# BMI: 52.58
# No. Of Children: 1
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $42112.24
# ---------------------------------------------------
# Actual Medical Insurance: $44501.4
# ---------------------------------------------------
#
# Details Of Patient 88:
# Age: 41
# Gender: Male
# BMI: 40.26
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $5699.84
# ---------------------------------------------------
# Actual Medical Insurance: $5709.16
# ---------------------------------------------------
#
# Details Of Patient 89:
# Age: 32
# Gender: Male
# BMI: 30.8
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $16796.41
# ---------------------------------------------------
# Actual Medical Insurance: $5253.52
# ---------------------------------------------------
#
# Details Of Patient 90:
# Age: 48
# Gender: Male
# BMI: 40.565
# No. Of Children: 2
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $42983.46
# ---------------------------------------------------
# Actual Medical Insurance: $45702.02
# ---------------------------------------------------
#
# Details Of Patient 91:
# Age: 50
# Gender: Male
# BMI: 34.2
# No. Of Children: 2
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $41661.6
# ---------------------------------------------------
# Actual Medical Insurance: $42856.84
# ---------------------------------------------------
#
# Details Of Patient 92:
# Age: 63
# Gender: Female
# BMI: 21.66
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $13616.36
# ---------------------------------------------------
# Actual Medical Insurance: $14449.85
# ---------------------------------------------------
#
# Details Of Patient 93:
# Age: 56
# Gender: Male
# BMI: 33.725
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10601.63
# ---------------------------------------------------
# Actual Medical Insurance: $10976.25
# ---------------------------------------------------
#
# Details Of Patient 94:
# Age: 20
# Gender: Female
# BMI: 33.0
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1877.93
# ---------------------------------------------------
# Actual Medical Insurance: $1880.07
# ---------------------------------------------------
#
# Details Of Patient 95:
# Age: 19
# Gender: Male
# BMI: 28.4
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2331.52
# ---------------------------------------------------
# Actual Medical Insurance: $1842.52
# ---------------------------------------------------
#
# Details Of Patient 96:
# Age: 57
# Gender: Female
# BMI: 28.7
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11840.78
# ---------------------------------------------------
# Actual Medical Insurance: $11455.28
# ---------------------------------------------------
#
# Details Of Patient 97:
# Age: 39
# Gender: Female
# BMI: 23.275
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7985.82
# ---------------------------------------------------
# Actual Medical Insurance: $7986.48
# ---------------------------------------------------
#
# Details Of Patient 98:
# Age: 63
# Gender: Male
# BMI: 41.47
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12982.87
# ---------------------------------------------------
# Actual Medical Insurance: $13405.39
# ---------------------------------------------------
#
# Details Of Patient 99:
# Age: 48
# Gender: Male
# BMI: 30.78
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8968.33
# ---------------------------------------------------
# Actual Medical Insurance: $10141.14
# ---------------------------------------------------
#
# Details Of Patient 100:
# Age: 19
# Gender: Male
# BMI: 26.03
# No. Of Children: 1
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $17178.68
# ---------------------------------------------------
# Actual Medical Insurance: $16450.89
# ---------------------------------------------------
#
# Details Of Patient 101:
# Age: 48
# Gender: Female
# BMI: 22.8
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9566.99
# ---------------------------------------------------
# Actual Medical Insurance: $8269.04
# ---------------------------------------------------
#
# Details Of Patient 102:
# Age: 55
# Gender: Female
# BMI: 32.395
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10928.85
# ---------------------------------------------------
# Actual Medical Insurance: $11879.1
# ---------------------------------------------------
#
# Details Of Patient 103:
# Age: 43
# Gender: Male
# BMI: 35.97
# No. Of Children: 3
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $41034.22
# ---------------------------------------------------
# Actual Medical Insurance: $42124.52
# ---------------------------------------------------
#
# Details Of Patient 104:
# Age: 63
# Gender: Male
# BMI: 41.325
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $15170.07
# ---------------------------------------------------
# Actual Medical Insurance: $15555.19
# ---------------------------------------------------
#
# Details Of Patient 105:
# Age: 46
# Gender: Female
# BMI: 27.74
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $24603.05
# ---------------------------------------------------
# Actual Medical Insurance: $8026.67
# ---------------------------------------------------
#
# Details Of Patient 106:
# Age: 44
# Gender: Male
# BMI: 30.69
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8219.2
# ---------------------------------------------------
# Actual Medical Insurance: $7731.43
# ---------------------------------------------------
#
# Details Of Patient 107:
# Age: 19
# Gender: Female
# BMI: 24.605
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2709.11
# ---------------------------------------------------
# Actual Medical Insurance: $2709.24
# ---------------------------------------------------
#
# Details Of Patient 108:
# Age: 37
# Gender: Female
# BMI: 34.8
# No. Of Children: 2
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $40103.89
# ---------------------------------------------------
# Actual Medical Insurance: $39836.52
# ---------------------------------------------------
#
# Details Of Patient 109:
# Age: 28
# Gender: Male
# BMI: 24.3
# No. Of Children: 5
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $5080.1
# ---------------------------------------------------
# Actual Medical Insurance: $5615.37
# ---------------------------------------------------
#
# Details Of Patient 110:
# Age: 34
# Gender: Female
# BMI: 23.56
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $5472.45
# ---------------------------------------------------
# Actual Medical Insurance: $4992.38
# ---------------------------------------------------
#
# Details Of Patient 111:
# Age: 34
# Gender: Male
# BMI: 30.8
# No. Of Children: 0
# Smoker: Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $37742.58
# ---------------------------------------------------
# Actual Medical Insurance: $35491.64
# ---------------------------------------------------
#
# Details Of Patient 112:
# Age: 54
# Gender: Male
# BMI: 24.035
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $25517.11
# ---------------------------------------------------
# Actual Medical Insurance: $10422.92
# ---------------------------------------------------
#
# Details Of Patient 113:
# Age: 23
# Gender: Male
# BMI: 32.7
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3987.93
# ---------------------------------------------------
# Actual Medical Insurance: $3591.48
# ---------------------------------------------------
#
# Details Of Patient 114:
# Age: 36
# Gender: Female
# BMI: 29.92
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4747.05
# ---------------------------------------------------
# Actual Medical Insurance: $5478.04
# ---------------------------------------------------
#
# Details Of Patient 115:
# Age: 24
# Gender: Female
# BMI: 39.49
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2464.62
# ---------------------------------------------------
# Actual Medical Insurance: $2480.98
# ---------------------------------------------------
#
# Details Of Patient 116:
# Age: 25
# Gender: Female
# BMI: 32.23
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3238.44
# ---------------------------------------------------
# Actual Medical Insurance: $18218.16
# ---------------------------------------------------
#
# Details Of Patient 117:
# Age: 42
# Gender: Male
# BMI: 24.64
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $21259.38
# ---------------------------------------------------
# Actual Medical Insurance: $19515.54
# ---------------------------------------------------
#
# Details Of Patient 118:
# Age: 21
# Gender: Male
# BMI: 23.21
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2150.47
# ---------------------------------------------------
# Actual Medical Insurance: $1515.34
# ---------------------------------------------------
#
# Details Of Patient 119:
# Age: 46
# Gender: Female
# BMI: 23.655
# No. Of Children: 1
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $35069.37
# ---------------------------------------------------
# Actual Medical Insurance: $21677.28
# ---------------------------------------------------
#
# Details Of Patient 120:
# Age: 25
# Gender: Male
# BMI: 26.22
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3070.81
# ---------------------------------------------------
# Actual Medical Insurance: $2721.32
# ---------------------------------------------------
#
# Details Of Patient 121:
# Age: 41
# Gender: Male
# BMI: 30.59
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6600.36
# ---------------------------------------------------
# Actual Medical Insurance: $7256.72
# ---------------------------------------------------
#
# Details Of Patient 122:
# Age: 18
# Gender: Male
# BMI: 21.78
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2803.7
# ---------------------------------------------------
# Actual Medical Insurance: $11884.05
# ---------------------------------------------------
#
# Details Of Patient 123:
# Age: 38
# Gender: Female
# BMI: 19.95
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $27375.9
# ---------------------------------------------------
# Actual Medical Insurance: $7133.9
# ---------------------------------------------------
#
# Details Of Patient 124:
# Age: 27
# Gender: Female
# BMI: 30.4
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6113.23
# ---------------------------------------------------
# Actual Medical Insurance: $18804.75
# ---------------------------------------------------
#
# Details Of Patient 125:
# Age: 54
# Gender: Male
# BMI: 31.6
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $24476.48
# ---------------------------------------------------
# Actual Medical Insurance: $9850.43
# ---------------------------------------------------
#
# Details Of Patient 126:
# Age: 52
# Gender: Female
# BMI: 44.7
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $30063.58
# ---------------------------------------------------
# Actual Medical Insurance: $11411.68
# ---------------------------------------------------
#
# Details Of Patient 127:
# Age: 26
# Gender: Male
# BMI: 31.065
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2523.17
# ---------------------------------------------------
# Actual Medical Insurance: $2699.57
# ---------------------------------------------------
#
# Details Of Patient 128:
# Age: 25
# Gender: Female
# BMI: 41.325
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3021.81
# ---------------------------------------------------
# Actual Medical Insurance: $17878.9
# ---------------------------------------------------
#
# Details Of Patient 129:
# Age: 32
# Gender: Male
# BMI: 33.82
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4076.5
# ---------------------------------------------------
# Actual Medical Insurance: $4462.72
# ---------------------------------------------------
#
# Details Of Patient 130:
# Age: 37
# Gender: Male
# BMI: 29.83
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6985.51
# ---------------------------------------------------
# Actual Medical Insurance: $6406.41
# ---------------------------------------------------
#
# Details Of Patient 131:
# Age: 46
# Gender: Male
# BMI: 25.8
# No. Of Children: 5
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9225.26
# ---------------------------------------------------
# Actual Medical Insurance: $10096.97
# ---------------------------------------------------
#
# Details Of Patient 132:
# Age: 53
# Gender: Female
# BMI: 32.3
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11881.97
# ---------------------------------------------------
# Actual Medical Insurance: $29186.48
# ---------------------------------------------------
#
# Details Of Patient 133:
# Age: 34
# Gender: Female
# BMI: 33.25
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $14358.36
# ---------------------------------------------------
# Actual Medical Insurance: $5594.85
# ---------------------------------------------------
#
# Details Of Patient 134:
# Age: 37
# Gender: Female
# BMI: 25.555
# No. Of Children: 1
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $19539.24
# ---------------------------------------------------
# Actual Medical Insurance: $20296.86
# ---------------------------------------------------
#
# Details Of Patient 135:
# Age: 45
# Gender: Male
# BMI: 24.035
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8302.54
# ---------------------------------------------------
# Actual Medical Insurance: $8604.48
# ...
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $5488.26
# ---------------------------------------------------
# Actual Medical Insurance: $6238.3
# ---------------------------------------------------
#
# Details Of Patient 292:
# Age: 36
# Gender: Male
# BMI: 30.875
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4402.23
# ---------------------------------------------------
# Actual Medical Insurance: $5373.36
# ---------------------------------------------------
#
# Details Of Patient 293:
# Age: 59
# Gender: Female
# BMI: 36.765
# No. Of Children: 1
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $48517.56
# ---------------------------------------------------
# Actual Medical Insurance: $47896.79
# ---------------------------------------------------
#
# Details Of Patient 294:
# Age: 47
# Gender: Male
# BMI: 36.2
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8334.59
# ---------------------------------------------------
# Actual Medical Insurance: $8068.19
# ---------------------------------------------------
#
# Details Of Patient 295:
# Age: 19
# Gender: Female
# BMI: 23.4
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1837.24
# ---------------------------------------------------
# Actual Medical Insurance: $2913.57
# ---------------------------------------------------
#
# Details Of Patient 296:
# Age: 23
# Gender: Male
# BMI: 17.385
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1964.78
# ---------------------------------------------------
# Actual Medical Insurance: $2775.19
# ---------------------------------------------------
#
# Details Of Patient 297:
# Age: 19
# Gender: Male
# BMI: 30.59
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1639.56
# ---------------------------------------------------
# Actual Medical Insurance: $1639.56
# ---------------------------------------------------
#
# Details Of Patient 298:
# Age: 62
# Gender: Female
# BMI: 32.965
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $15019.76
# ---------------------------------------------------
# Actual Medical Insurance: $15612.19
# ---------------------------------------------------
#
# Details Of Patient 299:
# Age: 52
# Gender: Male
# BMI: 24.32
# No. Of Children: 3
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $22412.65
# ---------------------------------------------------
# Actual Medical Insurance: $24869.84
# ---------------------------------------------------
#
# Details Of Patient 300:
# Age: 59
# Gender: Male
# BMI: 26.4
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12815.44
# ---------------------------------------------------
# Actual Medical Insurance: $11743.3
# ---------------------------------------------------
#
# Details Of Patient 301:
# Age: 32
# Gender: Female
# BMI: 23.65
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3561.89
# ---------------------------------------------------
# Actual Medical Insurance: $17626.24
# ---------------------------------------------------
#
# Details Of Patient 302:
# Age: 49
# Gender: Female
# BMI: 36.63
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $10702.64
# ---------------------------------------------------
# Actual Medical Insurance: $10381.48
# ---------------------------------------------------
#
# Details Of Patient 303:
# Age: 26
# Gender: Female
# BMI: 40.185
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3021.81
# ---------------------------------------------------
# Actual Medical Insurance: $3201.25
# ---------------------------------------------------
#
# Details Of Patient 304:
# Age: 18
# Gender: Female
# BMI: 28.215
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2196.47
# ---------------------------------------------------
# Actual Medical Insurance: $2200.83
# ---------------------------------------------------
#
# Details Of Patient 305:
# Age: 18
# Gender: Male
# BMI: 28.31
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2331.52
# ---------------------------------------------------
# Actual Medical Insurance: $11272.33
# ---------------------------------------------------
#
# Details Of Patient 306:
# Age: 39
# Gender: Female
# BMI: 34.1
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7201.7
# ---------------------------------------------------
# Actual Medical Insurance: $7418.52
# ---------------------------------------------------
#
# Details Of Patient 307:
# Age: 50
# Gender: Female
# BMI: 25.6
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9861.02
# ---------------------------------------------------
# Actual Medical Insurance: $8932.08
# ---------------------------------------------------
#
# Details Of Patient 308:
# Age: 42
# Gender: Male
# BMI: 34.1
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6571.02
# ---------------------------------------------------
# Actual Medical Insurance: $5979.73
# ---------------------------------------------------
#
# Details Of Patient 309:
# Age: 18
# Gender: Male
# BMI: 29.37
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3537.7
# ---------------------------------------------------
# Actual Medical Insurance: $1719.44
# ---------------------------------------------------
#
# Details Of Patient 310:
# Age: 48
# Gender: Female
# BMI: 36.575
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $26392.26
# ---------------------------------------------------
# Actual Medical Insurance: $8671.19
# ---------------------------------------------------
#
# Details Of Patient 311:
# Age: 19
# Gender: Female
# BMI: 27.93
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2331.52
# ---------------------------------------------------
# Actual Medical Insurance: $18838.7
# ---------------------------------------------------
#
# Details Of Patient 312:
# Age: 59
# Gender: Male
# BMI: 37.4
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12622.18
# ---------------------------------------------------
# Actual Medical Insurance: $21797.0
# ---------------------------------------------------
#
# Details Of Patient 313:
# Age: 37
# Gender: Female
# BMI: 29.5
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $7537.16
# ---------------------------------------------------
# Actual Medical Insurance: $6311.95
# ---------------------------------------------------
#
# Details Of Patient 314:
# Age: 58
# Gender: Female
# BMI: 33.1
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12430.95
# ---------------------------------------------------
# Actual Medical Insurance: $11848.14
# ---------------------------------------------------
#
# Details Of Patient 315:
# Age: 46
# Gender: Female
# BMI: 48.07
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9411.0
# ---------------------------------------------------
# Actual Medical Insurance: $9432.93
# ---------------------------------------------------
#
# Details Of Patient 316:
# Age: 30
# Gender: Female
# BMI: 30.9
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $3659.35
# ---------------------------------------------------
# Actual Medical Insurance: $5325.65
# ---------------------------------------------------
#
# Details Of Patient 317:
# Age: 26
# Gender: Male
# BMI: 29.45
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2727.4
# ---------------------------------------------------
# Actual Medical Insurance: $2897.32
# ---------------------------------------------------
#
# Details Of Patient 318:
# Age: 51
# Gender: Female
# BMI: 38.06
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $46255.11
# ---------------------------------------------------
# Actual Medical Insurance: $44400.41
# ---------------------------------------------------
#
# Details Of Patient 319:
# Age: 27
# Gender: Male
# BMI: 32.67
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $2498.41
# ---------------------------------------------------
# Actual Medical Insurance: $2497.04
# ---------------------------------------------------
#
# Details Of Patient 320:
# Age: 53
# Gender: Female
# BMI: 28.1
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11264.54
# ---------------------------------------------------
# Actual Medical Insurance: $11741.73
# ---------------------------------------------------
#
# Details Of Patient 321:
# Age: 52
# Gender: Male
# BMI: 47.74
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9140.95
# ---------------------------------------------------
# Actual Medical Insurance: $9748.91
# ---------------------------------------------------
#
# Details Of Patient 322:
# Age: 45
# Gender: Female
# BMI: 38.285
# No. Of Children: 0
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12797.21
# ---------------------------------------------------
# Actual Medical Insurance: $7935.29
# ---------------------------------------------------
#
# Details Of Patient 323:
# Age: 51
# Gender: Male
# BMI: 35.97
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $9304.7
# ---------------------------------------------------
# Actual Medical Insurance: $9386.16
# ---------------------------------------------------
#
# Details Of Patient 324:
# Age: 56
# Gender: Female
# BMI: 33.82
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $12269.69
# ---------------------------------------------------
# Actual Medical Insurance: $12643.38
# ---------------------------------------------------
#
# Details Of Patient 325:
# Age: 54
# Gender: Male
# BMI: 34.21
# No. Of Children: 2
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $43254.42
# ---------------------------------------------------
# Actual Medical Insurance: $44260.75
# ---------------------------------------------------
#
# Details Of Patient 326:
# Age: 31
# Gender: Male
# BMI: 26.885
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $4435.09
# ---------------------------------------------------
# Actual Medical Insurance: $4441.21
# ---------------------------------------------------
#
# Details Of Patient 327:
# Age: 23
# Gender: Female
# BMI: 28.31
# No. Of Children: 0
# Smoker: Smoker
# Region: North West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $17468.98
# ---------------------------------------------------
# Actual Medical Insurance: $18033.97
# ---------------------------------------------------
#
# Details Of Patient 328:
# Age: 44
# Gender: Male
# BMI: 29.735
# No. Of Children: 2
# Smoker: Non-Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $8219.2
# ---------------------------------------------------
# Actual Medical Insurance: $32108.66
# ---------------------------------------------------
#
# Details Of Patient 329:
# Age: 60
# Gender: Male
# BMI: 33.11
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $14590.63
# ---------------------------------------------------
# Actual Medical Insurance: $13919.82
# ---------------------------------------------------
#
# Details Of Patient 330:
# Age: 19
# Gender: Male
# BMI: 30.25
# No. Of Children: 0
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $33307.55
# ---------------------------------------------------
# Actual Medical Insurance: $32548.34
# ---------------------------------------------------
#
# Details Of Patient 331:
# Age: 51
# Gender: Male
# BMI: 42.9
# No. Of Children: 2
# Smoker: Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $47269.85
# ---------------------------------------------------
# Actual Medical Insurance: $47462.89
# ---------------------------------------------------
#
# Details Of Patient 332:
# Age: 18
# Gender: Male
# BMI: 35.2
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $1725.55
# ---------------------------------------------------
# Actual Medical Insurance: $1727.54
# ---------------------------------------------------
#
# Details Of Patient 333:
# Age: 29
# Gender: Female
# BMI: 21.755
# No. Of Children: 1
# Smoker: Smoker
# Region: North East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $20167.34
# ---------------------------------------------------
# Actual Medical Insurance: $16657.72
# ---------------------------------------------------
#
# Details Of Patient 334:
# Age: 41
# Gender: Male
# BMI: 34.21
# No. Of Children: 1
# Smoker: Non-Smoker
# Region: South East
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $6282.24
# ---------------------------------------------------
# Actual Medical Insurance: $6289.75
# ---------------------------------------------------
#
# Details Of Patient 335:
# Age: 53
# Gender: Male
# BMI: 28.6
# No. Of Children: 3
# Smoker: Non-Smoker
# Region: South West
# ---------------------------------------------------
# Estimated Medical Insurance (From Model): $11264.54
# ---------------------------------------------------
# Actual Medical Insurance: $11253.42
# ---------------------------------------------------

# %% [markdown]
# ### Evaluation
# Evaluate The Accuracy Of Your Model And How You Have Come To This Conclusion.

# %% [markdown]
# In This Experiment, I Used Machine Learning Using A Decision Tree Regressor As We Wanted To Predict A Quantity (Medical Insurance Cost) Based On The Input Data. The Model Produced Is Accurate To An Extent As Suggested By The $R^{2} Score$ Of 0.78 Which Is Close To 1.0 But Not Highly Accurate Which Suggests That This Model May Produce Erroneous Predictions In Some Cases Although This May Be Rare. Finally, The Above Summary For Each Patient With The Models Estimated Cost And The Actual Cost Is Relatively Similar For Most Patients Hence Suggesting That This Model Is Reliable And Useful.
